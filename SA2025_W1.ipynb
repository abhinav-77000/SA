# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
URL ="https://docs.google.com/spreadsheets/d/e/2PACX-1vS3IYmxl6Q6uy9nCOLJ5aZFHVOfZLcnzzGzfu-UKl3FV8hd_u7SoGyBTO0XSBqyQqNFGKObbWG2xFCW/pub?output=csv"
df = pd.read_csv(URL)

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
print(df.shape)
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
column_names = df.columns.to_numpy()
print(column_names)
# Out:
# ['mpg' 'cylinders' 'displacement' 'horsepower' 'weight' 'acceleration'
#  'model_year' 'origin' 'name']

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
df = df.set_index('name',drop=False)


print(df)
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin  \
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
#                                                 name
# name
# chevrolet chevelle malibu  chevrolet chevelle malibu
# buick skylark 320                  buick skylark 320
# plymouth satellite                plymouth satellite
# amc rebel sst                          amc rebel sst
# ford torino                              ford torino
# ...                                              ...
# ford mustang gl                      ford mustang gl
# vw pickup                                  vw pickup
# dodge rampage                          dodge rampage
# ford ranger                              ford ranger
# chevy s-10                                chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
# Print a list of all the unique mpg values
unique_mpg = df['mpg'].unique().tolist()
print(unique_mpg)
# Out:
# [18.0, 15.0, 16.0, 17.0, 14.0, 24.0, 22.0, 21.0, 27.0, 26.0, 25.0, 10.0, 11.0, 9.0, 28.0, 19.0, 12.0, 13.0, 23.0, 30.0, 31.0, 35.0, 20.0, 29.0, 32.0, 33.0, 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5, 26.5, 16.5, 31.5, 36.0, 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1, 32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1, 17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2, 19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2, 34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4, 24.3, 19.1, 34.3, 29.8, 31.3, 37.0, 32.2, 46.6, 27.9, 40.8, 44.3, 43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8, 23.5, 39.1, 39.0, 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9, 31.6, 28.1, 30.7, 24.2, 22.4, 34.0, 38.0, 44.0]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
# Create a new column with the metric: horsepower / weight
df['hp_per_weight'] = df['horsepower'] / df['weight']

# Set the new column as the index
df = df.set_index('hp_per_weight',drop=False)

print(df)
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# hp_per_weight
# 0.037100       18.0          8         307.0       130.0    3504
# 0.044679       15.0          8         350.0       165.0    3693
# 0.043655       18.0          8         318.0       150.0    3436
# 0.043694       16.0          8         304.0       150.0    3433
# 0.040591       17.0          8         302.0       140.0    3449
# ...             ...        ...           ...         ...     ...
# 0.030824       27.0          4         140.0        86.0    2790
# 0.024413       44.0          4          97.0        52.0    2130
# 0.036601       32.0          4         135.0        84.0    2295
# 0.030095       28.0          4         120.0        79.0    2625
# 0.030147       31.0          4         119.0        82.0    2720
#
#                acceleration  model_year  origin                       name  \
# hp_per_weight
# 0.037100               12.0          70     usa  chevrolet chevelle malibu
# 0.044679               11.5          70     usa          buick skylark 320
# 0.043655               11.0          70     usa         plymouth satellite
# 0.043694               12.0          70     usa              amc rebel sst
# 0.040591               10.5          70     usa                ford torino
# ...                     ...         ...     ...                        ...
# 0.030824               15.6          82     usa            ford mustang gl
# 0.024413               24.6          82  europe                  vw pickup
# 0.036601               11.6          82     usa              dodge rampage
# 0.030095               18.6          82     usa                ford ranger
# 0.030147               19.4          82     usa                 chevy s-10
#
#                hp_per_weight
# hp_per_weight
# 0.037100            0.037100
# 0.044679            0.044679
# 0.043655            0.043655
# 0.043694            0.043694
# 0.040591            0.040591
# ...                      ...
# 0.030824            0.030824
# 0.024413            0.024413
# 0.036601            0.036601
# 0.030095            0.030095
# 0.030147            0.030147
#
# [398 rows x 10 columns]

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
car_with_max_hp = df.loc[df['horsepower'].idxmax(), 'name']

print(car_with_max_hp)
# Out:
# pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
num_cars_mpg_35_or_more = (df['mpg'] >= 35).sum()
print(num_cars_mpg_35_or_more)
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
# Filter cars with horsepower > 100 and weight < 3000
filtered = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]

# Find the most common origin among these cars
most_common_origin = filtered['origin'].mode()[0]
print(most_common_origin)
# Out:
# usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
# Calculate the mean acceleration of cars from Japan, rounded to 2 decimals
mean_acc_japan = round(df[df['origin'] == 'japan']['acceleration'].mean(), 2)
print(mean_acc_japan)
# Out:
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
# Find the year with the highest average mpg
year_with_highest_avg_mpg = df.groupby('model_year')['mpg'].mean().idxmax()
print(year_with_highest_avg_mpg)
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
# Find the car(s) with the best ratio of horsepower to weight among all cars that also have above-median mpg

# Calculate the median mpg
median_mpg = df['mpg'].median()

# Filter cars with above-median mpg
above_median_mpg = df[df['mpg'] > median_mpg]

# Find the maximum hp_per_weight among these cars
max_hp_per_weight = above_median_mpg['hp_per_weight'].max()

# Get the car(s) with this best ratio
best_cars = above_median_mpg[above_median_mpg['hp_per_weight'] == max_hp_per_weight]

print(best_cars[['name', 'mpg', 'horsepower', 'weight', 'hp_per_weight']])
# Out:
#                    name   mpg  horsepower  weight  hp_per_weight
# hp_per_weight
# 0.050582       bmw 2002  26.0       113.0    2234       0.050582

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
import seaborn as sns

# Multi-line plot: Evolution of average mpg over the years, separately for each origin

import matplotlib.pyplot as plt

# Group by model_year and origin, then calculate mean mpg
mpg_by_year_origin = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=mpg_by_year_origin, x='model_year', y='mpg', hue='origin', marker='o')
plt.title('Evolution of Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
import seaborn as sns

# Create a Seaborn scatterplot where:
# X = horsepower, Y = weight, Color by: origin, Size by: mpg, Hue order = ['japan', 'europe', 'usa']

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    hue_order=['japan', 'europe', 'usa'],
    sizes=(40, 200),
    alpha=0.7
)
plt.title('Horsepower vs Weight of Cars\nColor: Origin, Size: MPG')
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
# Identify car names that appear in more than one model_year
name_counts = df.groupby('name')['model_year'].nunique()
multi_year_names = name_counts[name_counts > 1].index

# For each such name, compute the standard deviation of mpg across years
consistent_cars = (
    df[df['name'].isin(multi_year_names)]
    .groupby('name')
    .agg(
        num_years=('model_year', 'nunique'),
        mpg_std=('mpg', 'std'),
        avg_mpg=('mpg', 'mean')
    )
    .reset_index()
)

# Filter for std(mpg) < 1.0 and at least 2 appearances
consistent_cars = consistent_cars[
    (consistent_cars['mpg_std'] < 1.0) & (consistent_cars['num_years'] >= 2)
]

# Sort by number of appearances (descending), then avg_mpg (descending)
consistent_cars = consistent_cars.sort_values(
    by=['num_years', 'avg_mpg'], ascending=[False, False]
)

# Show model name(s), number of appearances, and average mpg
print(consistent_cars[['name', 'num_years', 'avg_mpg']])
# Out:
#                          name  num_years    avg_mpg
# 26           ford galaxie 500          3  14.333333
# 41          plymouth fury iii          3  14.333333
# 49        toyota corolla 1200          2  31.500000
# 35                  mazda 626          2  31.450000
# 53          volkswagen rabbit          2  29.250000
# 21               datsun pl510          2  27.000000
# 45                  saab 99le          2  24.500000
# 51             toyota mark ii          2  19.500000
# 22                dodge aspen          2  18.850000
# 10  chevrolet chevelle malibu          2  17.500000
# 4            amc matador (sw)          2  14.500000
# 28      ford gran torino (sw)          2  13.500000
# 29                   ford ltd          2  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
